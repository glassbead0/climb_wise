# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
from category_encoders import OrdinalEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import classification_report
import sys
import importlib
sys.path.append('/app/mtn_proj_ticks/')
import climbing_ticks_helper as helper
importlib.reload(helper)
pd.set_option('display.expand_frame_repr', False) # display full data in terminal
# %matplotlib inline

df_raw = pd.read_csv("/app/ticks.csv")
df_generic = df_raw[df_raw['Location'].str.contains('Generic Area')]
df_generic_chatgpt = pd.read_csv("/app/generic_chatgpt.csv")
df_generic_chatgpt[0:30]
# Out:
#     Unnamed: 0        Date                      Route   Rating  Notes                                                URL  Pitches                                   Location  Avg Stars  Your Stars    Style Lead Style Route Type  Your Rating Length  Rating Code
# 0          491  2023-09-14  Adam's Route Left Buffalo  5.11c/d    NaN  https://www.mountainproject.com/route/491Generic/        1             North Chickamauga, Chattanooga        3.3          -1     Lead  Fell/Hung      Sport          NaN                5400
# 1          492  2023-09-14                 Keegerator  5.11b/c    NaN  https://www.mountainproject.com/route/492Generic/        1             North Chickamauga, Chattanooga        3.0          -1     Lead        NaN      Sport          NaN                5100
# 2          493  2023-09-14             Long Fun Route  5.10b/c    NaN  https://www.mountainproject.com/route/493Generic/        1             North Chickamauga, Chattanooga        2.9          -1     Lead    Onsight      Sport          NaN                3100
# 3          494  2023-09-08    Traverse From Land Left  5.10b/c    NaN  https://www.mountainproject.com/route/494Generic/        1      Summersville Lake SWS at the Rat Hole        2.9          -1     Solo        NaN      Sport          NaN                3100
# 4          499  2023-09-03                  DWS Route    5.12b    NaN  https://www.mountainproject.com/route/499Generic/        1            The Rat Hole, Summersville Lake        3.1          -1     Solo        NaN      Sport          NaN                6900
# 5          503  2023-09-03                  Reticulum    5.10d    NaN  https://www.mountainproject.com/route/503Generic/        1                          Summersville Lake        2.9          -1     Solo        NaN      Sport          NaN                3500
# 6          504  2023-09-03                  DWS Route      5.9    NaN  https://www.mountainproject.com/route/499Generic/        1                          Summersville Lake        2.4          -1     Solo        NaN      Sport          NaN                2400
# 7          510  2023-09-01          DWS Left Coliseum    5.11a    NaN  https://www.mountainproject.com/route/510Generic/        1                          Summersville Lake        2.9          -1     Solo        NaN      Sport          NaN                4600
# 8          514  2023-08-31          DWS Rounded Arete    5.10a    NaN  https://www.mountainproject.com/route/514Generic/        1                                    unknown        2.6          -1     Solo        NaN      Sport          NaN                2600
# 9          578  2023-07-19       Trailside Arete Left       V4    NaN  https://www.mountainproject.com/route/578Generic/        3                               Lincoln Lake        3.3          -1  Attempt        NaN    Boulder          NaN               20400
# 10         579  2023-07-18     Arete Right Powder Keg       V1    NaN  https://www.mountainproject.com/route/579Generic/        1                               Lincoln Lake        2.8          -1    Flash        NaN    Boulder          NaN               20100
# 11         580  2023-07-18   Lincoln in an Easy Chair       V5    NaN  https://www.mountainproject.com/route/580Generic/        1                               Lincoln Lake        3.0          -1     Send        NaN    Boulder          NaN               20500
# 12         627  2023-03-27               Ladies First       V2    NaN  https://www.mountainproject.com/route/627Generic/        1          Ezekiel wall, Middle Mesteno, Roy        3.1          -1    Flash        NaN    Boulder          NaN               20200
# 13         628  2023-03-27                  90% Cocoa       V2    NaN  https://www.mountainproject.com/route/628Generic/        1          Ezekiel Wall, Middle Mesteno, Roy        3.1          -1     Send        NaN    Boulder          NaN               20200
# 14         640  2023-03-24       Snail Trail (corner)       V0    NaN  https://www.mountainproject.com/route/640Generic/        1          Ezekiel wall, Middle Mesteno, Roy        2.6          -1    Flash        NaN    Boulder          NaN               20008
# 15         684  2023-01-08                  The Strip       V7    NaN  https://www.mountainproject.com/route/684Generic/        1                                      Vegas        3.4          -1  Attempt        NaN    Boulder          NaN               20700
# 16         732  2022-08-19                 Outrageous    5.12b    NaN  https://www.mountainproject.com/route/732Generic/        1            The colliseum, Vancouver Island        3.1          -1     Lead        NaN      Sport          NaN                6900
# 17         733  2022-08-19                 Abbey Road      5.9    NaN  https://www.mountainproject.com/route/733Generic/        1              Beechy Head, Vancouver Island        3.2          -1     Lead        NaN       Trad          NaN                2400
# 18         734  2022-08-19                  Whaleback      5.8    NaN  https://www.mountainproject.com/route/734Generic/        1              Beechy Head, Vancouver Island        2.7          -1     Lead        NaN      Sport          NaN                2100
# 19         748  2022-08-10                    Sidecar      5.6    NaN  https://www.mountainproject.com/route/748Generic/        1                                   Squamish        1.8          -1     Solo        NaN      Sport          NaN                1600
# 20         749  2022-08-10              Channel No. 5      5.5    NaN  https://www.mountainproject.com/route/749Generic/        1      Free and Easy, Smoke Bluffs, Squamish        1.9          -1     Solo        NaN      Sport          NaN                1500
# 21         750  2022-08-10                   Elsinore      5.5    NaN  https://www.mountainproject.com/route/750Generic/        1      Free and Easy, Smoke Bluffs, Squamish        1.9          -1     Solo        NaN      Sport          NaN                1500
# 22         751  2022-08-10              Unknown Route      5.5    NaN  https://www.mountainproject.com/route/751Generic/        1  Island in the Sky, Smoke Bluffs, Squamish        1.9          -1     Solo        NaN      Sport          NaN                1500
# 23         755  2022-08-09                   Maxi Pad       V7    NaN  https://www.mountainproject.com/route/755Generic/        1              The Clean Boulders,  Squamish        3.4          -1     Send        NaN    Boulder          NaN               20700
# 24         756  2022-08-09                   Maxi Pad       V7    NaN  https://www.mountainproject.com/route/755Generic/        4              The Clean Boulders,  Squamish        3.4          -1  Attempt        NaN    Boulder          NaN               20700
# 25         789  2022-07-30   Shannon Springs Traverse      5.6    NaN  https://www.mountainproject.com/route/789Generic/        1                                   Squamish        1.8          -1     Lead        NaN      Sport          NaN                1600
# 26         794  2022-07-29                 Deflowered    5.11b    NaN  https://www.mountainproject.com/route/794Generic/        1                    Debeques Hill, Squamish        2.9          -1     Lead    Onsight      Sport          NaN                4900
# 27         795  2022-07-29             Permit Process    5.11a    NaN  https://www.mountainproject.com/route/795Generic/        1                    Debeques Hill, Squamish        2.9          -1     Lead    Onsight      Sport          NaN                4600
# 28         796  2022-07-29              Three Pistols    5.10d    NaN  https://www.mountainproject.com/route/796Generic/        1                    Debeques Hill, Squamish        2.9          -1     Lead    Onsight      Sport          NaN                3500
# 29         797  2022-07-29                 Easy Tango      5.8    NaN  https://www.mountainproject.com/route/797Generic/        1                    Debeques Hill, Squamish        2.7          -1     Lead    Onsight      Sport          NaN                2100
